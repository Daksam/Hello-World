# %% [markdown]
# # FILTERING AND EXTRACTING DATA IN PYTHON ASSIGNMENT

# %% [markdown]
# ## 1. From the police.csv dataset

# %%
import pandas as pd
import numpy as np
import os

# %%
police_dt = pd.read_csv("police.csv")

# %%
police_dt
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# ...

# %%
police_dt.head()
# Out:
#   state   stop_date stop_time  county_name driver_gender driver_race  \
# 0    RI  2005-01-04     12:55          NaN             M       White
# 1    RI  2005-01-23     23:15          NaN             M       White
# 2    RI  2005-02-17     04:15          NaN             M       White
# 3    RI  2005-02-20     17:15          NaN             M       White
# 4    RI  2005-02-24     01:20          NaN             F       White
#
#                     violation_raw  violation  search_conducted search_type  \
# 0  Equipment/Inspection Violation  Equipment             False         NaN
# 1                        Speeding   Speeding             False         NaN
# 2                        Speeding   Speeding             False         NaN
# 3                Call for Service      Other             False         NaN
# 4                        Speeding   Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop district
# ...

# %%
police_dt.tail()
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 91736    RI  2015-12-31     21:21          NaN             F       Black
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91739    RI  2015-12-31     22:09          NaN             F    Hispanic
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# 91736         Other Traffic Violation     Moving violation             False
# 91737                        Speeding             Speeding             False
# 91738         Other Traffic Violation     Moving violation             False
# 91739  Equipment/Inspection Violation            Equipment             False
# 91740          Registration Violation  Registration/plates             False
#
# ...

# %%
police_dt.shape
# Out:
# (91741, 15)

# %%
police_dt.dropna()
# Out:
# Empty DataFrame
# Columns: [state, stop_date, stop_time, county_name, driver_gender, driver_race, violation_raw, violation, search_conducted, search_type, stop_outcome, is_arrested, stop_duration, drugs_related_stop, district]
# Index: []

# %% [markdown]
# ### a. what percentage of female had a violation of speeding?

# %%
speed = police_dt[police_dt.violation == 'Speeding']
speed
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# 5        RI  2005-03-14     10:00          NaN             F       White
# 6        RI  2005-03-29     21:55          NaN             M       White
# ...     ...         ...       ...          ...           ...         ...
# 91731    RI  2015-12-31     13:23          NaN             M       White
# 91732    RI  2015-12-31     18:59          NaN             M       White
# 91734    RI  2015-12-31     20:20          NaN             M       White
# 91735    RI  2015-12-31     20:50          NaN             M       White
# 91737    RI  2015-12-31     21:59          NaN             F       White
#
#       violation_raw violation  search_conducted search_type stop_outcome  \
# ...

# %%
# Calculating the percentage of female had a violation of speeding

speedf = speed.driver_gender.value_counts(normalize=True)*100
speedf.loc['F'].round(2)
# Out:
# 32.31

# %% [markdown]
# ###  b. How many of the arrested drivers were male and what was their race?

# %%
# filtering all male drivers who were arrested and their races

#male = police_dt[['driver_gender', 'is_arrested', 'driver_race']]
#male

male_arest = male[(male['driver_gender']=='M') & (male['is_arrested']=='True')]
male_arest
# Out:
# Empty DataFrame
# Columns: [driver_gender, is_arrested, driver_race]
# Index: []

# %%
# finding their number

(male['driver_gender']=='M').sum()
# Out:
# 62762

# %% [markdown]
# ### c. In different tables, show the various stop outcomes and their respective violations

# %%
#selecting stop outcome and violations columns

police_dt[['stop_outcome', 'violation']]
# Out:
#         stop_outcome            violation
# 0           Citation            Equipment
# 1           Citation             Speeding
# 2           Citation             Speeding
# 3      Arrest Driver                Other
# 4           Citation             Speeding
# ...              ...                  ...
# 91736       Citation     Moving violation
# 91737       Citation             Speeding
# 91738       Citation     Moving violation
# 91739        Warning            Equipment
# 91740       Citation  Registration/plates
#
# [91741 rows x 2 columns]

# %% [markdown]
# ### d.i. What percentage of drivers who were stopped were black, how many were drug related, did it lead to an arrest? If it led to an arrest, how many?

# %%
b_stop = police_dt[police_dt.driver_race =='Black']
b_stop
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 26       RI  2005-10-01     06:15          NaN             M       Black
# 28       RI  2005-10-01     08:49          NaN             M       Black
# 51       RI  2005-10-01     23:50          NaN             F       Black
# 67       RI  2005-10-02     12:55          NaN             M       Black
# 70       RI  2005-10-02     15:30          NaN             M       Black
# ...     ...         ...       ...          ...           ...         ...
# 91698    RI  2015-12-30     02:15          NaN             M       Black
# 91699    RI  2015-12-30     02:34          NaN             M       Black
# 91700    RI  2015-12-30     03:30          NaN             F       Black
# 91705    RI  2015-12-30     09:46          NaN             M       Black
# 91736    RI  2015-12-31     21:21          NaN             F       Black
#
#                         violation_raw         violation  search_conducted  \
# ...

# %%
drug_stop = b_stop[b_stop.drugs_related_stop =='True']
drug_stop
# Out:
# Empty DataFrame
# Columns: [state, stop_date, stop_time, county_name, driver_gender, driver_race, violation_raw, violation, search_conducted, search_type, stop_outcome, is_arrested, stop_duration, drugs_related_stop, district]
# Index: []

# %% [markdown]
# ###     ii. What percentage of drivers who were stopped were white, how many were drug related, did it lead to an arrest? If it led to an arrest, how many?

# %%
w_stop = police_dt[police_dt.driver_race =='White']
w_stop
# Out:
#       state   stop_date stop_time  county_name driver_gender driver_race  \
# 0        RI  2005-01-04     12:55          NaN             M       White
# 1        RI  2005-01-23     23:15          NaN             M       White
# 2        RI  2005-02-17     04:15          NaN             M       White
# 3        RI  2005-02-20     17:15          NaN             M       White
# 4        RI  2005-02-24     01:20          NaN             F       White
# ...     ...         ...       ...          ...           ...         ...
# 91734    RI  2015-12-31     20:20          NaN             M       White
# 91735    RI  2015-12-31     20:50          NaN             M       White
# 91737    RI  2015-12-31     21:59          NaN             F       White
# 91738    RI  2015-12-31     22:04          NaN             M       White
# 91740    RI  2015-12-31     22:47          NaN             M       White
#
#                         violation_raw            violation  search_conducted  \
# ...

# %%
drug_stop = w_stop[w_stop.drugs_related_stop =='True']
drug_stop
# Out:
# Empty DataFrame
# Columns: [state, stop_date, stop_time, county_name, driver_gender, driver_race, violation_raw, violation, search_conducted, search_type, stop_outcome, is_arrested, stop_duration, drugs_related_stop, district]
# Index: []

# %% [markdown]
# ## 2. From the instagram_global_top_1000 dataset, answer the following questions

# %%
ig_global = pd.read_csv("instagram_global_top_1000.csv")
ig_global
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
ig_global_drop = ig_global.dropna()
ig_global_drop
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
ig_global.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# ...

# %%
ig_global.tail()
# Out:
#     Country  Rank        Account                           Title  \
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 995  https://www.instagram.com/senoritasaeva/
# 996    https://www.instagram.com/manuelneuer/
# 997      https://www.instagram.com/sahilkhan/
# 998    https://www.instagram.com/mohanshakti/
# 999       https://www.instagram.com/eduincaz/
#
#                                 Category   Followers Audience Country  \
# 995             Lifestyle|Music|Modeling   7700000.0           Russia
# 996                   Sports with a ball  11500000.0          Germany
# 997                          Fitness|Gym  10100000.0            India
# ...

# %% [markdown]
# ### a. How many influencers in the top 20 are into sports?

# %%
ig_global_drop.head(20).Category.str.contains('Sports').sum()
# Out:
# 4

# %% [markdown]
# ### b. How many musicians were in the top 100, which countries were their audience from and how many followers did they have?

# %%
# top 100 from the cleaned global data
top_music = ig_global_drop.head(100)
top_music
# Out:
#     Country  Rank               Account               Title  \
# 0       All     1             cristiano   Cristiano Ronaldo
# 1       All     2           kyliejenner             Kylie 🤍
# 2       All     3              leomessi           Leo Messi
# 3       All     4         kendalljenner             Kendall
# 4       All     5           selenagomez        Selena Gomez
# ..      ...   ...                   ...                 ...
# 104     All   105            camimendes       camila mendes
# 105     All   106             theweeknd          The Weeknd
# 106     All   107            norafatehi         Nora Fatehi
# 107     All   108  iamzlatanibrahimovic  Zlatan Ibrahimović
# 108     All   109          karimbenzema       Karim Benzema
#
#                                                 Link  \
# 0               https://www.instagram.com/cristiano/
# 1             https://www.instagram.com/kyliejenner/
# 2                https://www.instagram.com/leomessi/
# ...

# %%
#finding the  influers in the top 100 who are into music

top_music_dt = top_music[top_music.Category.str.contains('Music')]
top_music_dt
# Out:
#     Country  Rank            Account           Title  \
# 4       All     5        selenagomez    Selena Gomez
# 7       All     8            beyonce        Beyoncé
# 8       All     9       arianagrande   Ariana Grande
# 9       All    10       billieeilish   BILLIE EILISH
# 11      All    12       lalalalisa_m            LISA
# 12      All    13     jennierubyjane               J
# 18      All    19          sooyaaa__          JISOO🤍
# 19      All    20       justinbieber   Justin Bieber
# 21      All    22    roses_are_rosie           ROSÉ
# 22      All    23         badgalriri      badgalriri
# 23      All    24         nickiminaj          Barbie
# 24      All    25          iamcardib         Cardi B
# 29      All    30               zayn      Zayn Malik
# 30      All    31      champagnepapi   champagnepapi
# 36      All    37              adele           Adele
# 39      All    40                jlo  Jennifer Lopez
# 41      All    42             karolg         KAROL G
# ...

# %%
# finding the number musicians in the top of 100 influencers
top_music.Category.str.contains('Music').sum()
# Out:
# 35

# %%
# The details of the top 100 influencers who are into music

a = top_music_dt.iloc[0: ,2:8]
a
# Out:
#                Account           Title  \
# 4          selenagomez    Selena Gomez
# 7              beyonce        Beyoncé
# 8         arianagrande   Ariana Grande
# 9         billieeilish   BILLIE EILISH
# 11        lalalalisa_m            LISA
# 12      jennierubyjane               J
# 18           sooyaaa__          JISOO🤍
# 19        justinbieber   Justin Bieber
# 21     roses_are_rosie           ROSÉ
# 22          badgalriri      badgalriri
# 23          nickiminaj          Barbie
# 24           iamcardib         Cardi B
# 29                zayn      Zayn Malik
# 30       champagnepapi   champagnepapi
# 36               adele           Adele
# 39                 jlo  Jennifer Lopez
# 41              karolg         KAROL G
# 45           eunwo.o_c             차은우
# 46             dualipa        DUA LIPA
# 49          mileycyrus     Miley Cyrus
# 55         shawnmendes    Shawn Mendes
# 59       oliviarodrigo  Olivia Rodrigo
# 62            lelepons       Lele Pons
# ...

# %% [markdown]
# ### c. Find out how many influencers had Indian audiences, their profession, their number of followers and their average engagement.

# %%
b = ig_global_drop.iloc[0:, 2:10]
b

b_drop = b.drop(columns=["Link","Authentic engagement"])
b_drop
# Out:
#            Account                           Title  \
# 0        cristiano               Cristiano Ronaldo
# 1      kyliejenner                         Kylie 🤍
# 2         leomessi                       Leo Messi
# 3    kendalljenner                         Kendall
# 4      selenagomez                    Selena Gomez
# ..             ...                             ...
# 995  senoritasaeva                      Dina Saeva
# 996    manuelneuer                    Manuel Neuer
# 997      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998    mohanshakti                    Shakti Mohan
# 999       eduincaz                       Eduin Caz
#
#                                 Category    Followers Audience Country  \
# 0                     Sports with a ball  400100000.0            India
# 1                Fashion|Modeling|Beauty  308800000.0    United States
# 2              Sports with a ball|Family  306300000.0        Argentina
# ...

# %%
b_drop1 = b_drop[(b_drop['Audience Country']=='India')]
b_drop1
# Out:
#                     Account                           Title  \
# 0                 cristiano               Cristiano Ronaldo
# 14              virat.kohli                     Virat Kohli
# 19             justinbieber                   Justin Bieber
# 27                  therock                         therock
# 28                instagram                       Instagram
# ..                      ...                             ...
# 949  divyankatripathidahiya        Divyanka Tripathi Dahiya
# 973         ravindra.jadeja             Ravindrasinh jadeja
# 986              rishabpant                    Rishabh Pant
# 997               sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998             mohanshakti                    Shakti Mohan
#
#                                 Category    Followers Audience Country  \
# 0                     Sports with a ball  400100000.0            India
# 14                    Sports with a ball  182600000.0            India
# ...

# %%
#finding the number of influencers who had Indian audiences, their profession, their number of followers and their average engagement.
(b_drop['Audience Country']=='India').sum()
# Out:
# 137

# %% [markdown]
# ### d. What percentage of influencers with average engagement less than 1.5 million were into Beauty and Lifestyle?

# %%
b_lifestyle = ig_global_drop[ig_global_drop.Category.str.contains('Beauty','Lifestyle')]
b_lifestyle
# Out:
#     Country  Rank                    Account                      Title  \
# 1       All     2                kyliejenner                    Kylie 🤍
# 6       All     7              kimkardashian        Kim Kardashian West
# 18      All    19                  sooyaaa__                     JISOO🤍
# 22      All    23                 badgalriri                 badgalriri
# 35      All    36                katrinakaif               Katrina Kaif
# 61      All    62          rashmika_mandanna          Rashmika Mandanna
# 91      All    92                addisonraee                Addison Rae
# 173     All   174                 sadiesink_                 Sadie Sink
# 176     All   177     samantharuthprabhuoffl                   Samantha
# 215     All   216                 sunnyleone                Sunny Leone
# 225     All   226            natashawilona12             Natasha Wilona
# 259     All   260                bretmanrock  Bretman (Da Baddest) Rock
# ...

# %%
b_lifestyle[(b_lifestyle['Engagement avg'] < 1500000)]
# Out:
#     Country  Rank                    Account                      Title  \
# 91      All    92                addisonraee                Addison Rae
# 176     All   177     samantharuthprabhuoffl                   Samantha
# 215     All   216                 sunnyleone                Sunny Leone
# 225     All   226            natashawilona12             Natasha Wilona
# 259     All   260                bretmanrock  Bretman (Da Baddest) Rock
# 261     All   262                 krisjenner                Kris Jenner
# 263     All   264               jamescharles              James Charles
# 292     All   293             chiaraferragni          Chiara Ferragni ✨
# 301     All   302                  marimaria                 Mari Maria
# 344     All   345                      avani                      avani
# 354     All   355                   ler_chek           Валерия Чекалина
# 370     All   371               bernardokath         Kathryn Bernardo 🐘
# ...

# %%
blife = (b_lifestyle['Engagement avg'] < 1500000).sum()
blife
# Out:
# 34

# %%
# finding the percentage of influencers with average engagement less than 1.5 million were into Beauty and Lifestyle

blife_cent = (blife/891*100).round(2)
blife_cent
# Out:
# 3.82

# %% [markdown]
# ### e. What percentage of the influencers were into Sports with a ball, find out the difference between their average engagements and authentic engagements?

# %%
sports = ig_global_drop[ig_global_drop.Category.str.contains('Sports with a ball')]
sports
# Out:
#     Country  Rank          Account                Title  \
# 0       All     1        cristiano    Cristiano Ronaldo
# 2       All     3         leomessi            Leo Messi
# 10      All    11         neymarjr                NJ 🇧🇷
# 14      All    15      virat.kohli          Virat Kohli
# 38      All    39        kingjames                    👑
# ..      ...   ...              ...                  ...
# 972     All   973      davidluiz23           David Luiz
# 973     All   974  ravindra.jadeja  Ravindrasinh jadeja
# 983     All   984         casemiro             Casemiro
# 986     All   987       rishabpant         Rishabh Pant
# 996     All   997      manuelneuer         Manuel Neuer
#
#                                            Link                      Category  \
# 0          https://www.instagram.com/cristiano/            Sports with a ball
# 2           https://www.instagram.com/leomessi/     Sports with a ball|Family
# ...

# %%
sports_sum = ig_global_drop.Category.str.contains('Sports with a ball').sum()
sports_sum
# Out:
# 117

# %%
(sports_sum/891*100).round(2)
# Out:
# 13.13

# %%
sports['Engagement avg'] - sports['Authentic engagement']
# Out:
# 0      1700000.0
# 2      1700000.0
# 10     1200000.0
# 14      300000.0
# 38      615700.0
#          ...
# 972      65100.0
# 973     112000.0
# 983      60300.0
# 986      68500.0
# 996      63700.0
# Length: 117, dtype: float64
